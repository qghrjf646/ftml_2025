# %% [markdown]
# ### Load Dataset & imports

# %%
import numpy as np
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score


# Charger les données
X_train = np.load("../data/classification/X_train.npy")
y_train = np.load("../data/classification/y_train.npy")
X_test = np.load('../data/classification/X_test.npy')
y_test = np.load('../data/classification/y_test.npy')

# %% [markdown]
# ## Gridsearch for each model

# %% [markdown]
# ### Logistic Regression
#
# During the grid search process, we encountered several warnings indicating that certain combinations of `penalty` and `solver` are incompatible. These configurations were automatically skipped by scikit-learn, which is expected behavior. Despite testing various settings (including different regularization strengths and penalties such as `"l1"`, `"l2"`, and `"elasticnet"`), the best test accuracy we were able to achieve peaked at **0.746**. This performance remained significantly below the target of 0.85, suggesting that logistic regression may not be well suited for this particular dataset, likely due to its linear decision boundary limitations.

# %%
# Model parameters
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression(max_iter=5000))
])
param_grid = {"clf__C": [0.01, 0.05, 0.1, 0.2 ,0.4, 0.8, 1, 2, 5, 10], "clf__penalty": ["l2", "l1", "elasticnet"], "clf__solver": ["lbfgs", "liblinear", "saga", "newton-cg", "newton-cholesky", "sag", "saga"]}

# Execute GridSearchCV
grid = GridSearchCV(pipe, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid.fit(X_train, y_train)
print(f"Logistic Regression:\n  Best CV Accuracy: {grid.best_score_:.4f}")
print(f"  Best Params: {grid.best_params_}")
best_model = grid.best_estimator_

# Evaluate on test set
y_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred)

print(f"  Test set accuracy: {test_accuracy}\n")
# Out:
# Logistic Regression:
#   Best CV Accuracy: 0.7165
#   Best Params: {'clf__C': 0.05, 'clf__penalty': 'l1', 'clf__solver': 'saga'}
#   Test set accuracy: 0.746
# /Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:516: FitFailedWarning:
# 550 fits failed out of a total of 1050.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/pipeline.py", line 661, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1210, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/pipeline.py", line 661, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1210, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/pipeline.py", line 661, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1210, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cholesky supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/pipeline.py", line 661, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1210, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/pipeline.py", line 661, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1210, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/pipeline.py", line 661, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1210, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 71, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 100 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/pipeline.py", line 661, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1220, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/pipeline.py", line 661, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1210, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/pipeline.py", line 661, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1210, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cholesky supports only 'l2' or None penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/pipeline.py", line 661, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/base.py", line 1363, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1210, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or None penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/leo/Documents/s8/ftml_2025/.venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1135: UserWarning: One or more of the test scores are non-finite: [0.7075 0.709  0.7075 0.7075 0.7075 0.7075 0.7075    nan 0.702  0.7025
#     nan    nan    nan 0.7025    nan    nan    nan    nan    nan    nan
#     nan 0.7145 0.715  0.7145 0.7145 0.7145 0.7145 0.7145    nan 0.713
#  0.7165    nan    nan    nan 0.7165    nan    nan    nan    nan    nan
#     nan    nan 0.7145 0.715  0.7145 0.7145 0.7145 0.7145 0.7145    nan
#  0.7135 0.715     nan    nan    nan 0.715     nan    nan    nan    nan
#     nan    nan    nan 0.7145 0.7145 0.7145 0.7145 0.7145 0.7145 0.7145
#     nan 0.7135 0.714     nan    nan    nan 0.714     nan    nan    nan
#     nan    nan    nan    nan 0.714  0.714  0.714  0.714  0.714  0.714
#  0.714     nan 0.713  0.7135    nan    nan    nan 0.7135    nan    nan
#     nan    nan    nan    nan    nan 0.7145 0.7145 0.7145 0.7145 0.7145
#  0.7145 0.7145    nan 0.7125 0.7125    nan    nan    nan 0.7125    nan
#     nan    nan    nan    nan    nan    nan 0.7145 0.7145 0.7145 0.7145
#  0.7145 0.7145 0.7145    nan 0.7135 0.713     nan    nan    nan 0.713
#     nan    nan    nan    nan    nan    nan    nan 0.7145 0.7145 0.7145
#  0.7145 0.7145 0.7145 0.7145    nan 0.7135 0.7125    nan    nan    nan
#  0.7125    nan    nan    nan    nan    nan    nan    nan 0.7145 0.7145
#  0.7145 0.7145 0.7145 0.7145 0.7145    nan 0.714  0.714     nan    nan
#     nan 0.714     nan    nan    nan    nan    nan    nan    nan 0.7145
#  0.7145 0.7145 0.7145 0.7145 0.7145 0.7145    nan 0.7145 0.7145    nan
#     nan    nan 0.7145    nan    nan    nan    nan    nan    nan    nan]
#   warnings.warn(

# %% [markdown]
# ### SVC
#
# We initially explored various kernels using a basic set of hyperparameters and observed that the most performant one was `"rbf"`, reaching a test accuracy of approximately **0.80**. However, further improvements with this kernel were limited, as `"rbf"` does not leverage additional tunable parameters like `coef0` or `degree`. While we could have attempted finer tuning of `C` or `gamma`, the performance plateau suggested diminishing returns.
#
# We therefore decided to shift focus to the `"poly"` kernel, which was the second-best performer in early experiments. This choice allowed us to explore additional hyperparameters such as `coef0` and `degree`, which are exclusive to the polynomial kernel. Interestingly, we found that the optimal value for `degree` consistently remained at **3**, the default, so we opted not to further tune this parameter.
#
# In our refined grid search, we observed that the best models systematically preferred `gamma="scale"` over numeric values, allowing us to reduce the search space and computational cost. Additionally, the most promising results were obtained with `C` values around **3** and `coef0` values near **0.03**.
#
# One of the most impactful discoveries was that **removing the `StandardScaler`** from the pipeline significantly improved performance. This change alone boosted our test accuracy from **0.822** to a peak of **0.8895**, surpassing the 0.85 target and confirming the sensitivity of SVMs to input scaling when using certain kernels.

# %%
# Model parameters

# First step (all kernels)
# pipe = Pipeline([
#     ('scaler', StandardScaler()),
#     ('clf', SVC())
# ])
# param_grid = {"clf__C": [0.05, 0.1, 0.5, 1.0, 3.0, 5.0, 10.0], "clf__kernel": ["poly", "rbf", "linear", "sigmoid"], "clf__gamma": ["scale", "auto", 0, 0.5, 1, 5, 10]}

# Focus on "poly" kernel
pipe = Pipeline([
    ('clf', SVC())
])
param_grid = {"clf__C": [2.3, 2.5, 3.0, 3.5, 3.7, 4.0], "clf__kernel": ["poly"], "clf__gamma": ["scale", "auto"], "clf__coef0": [0.00, 0.005, 0.01, 0.02, 0.03, 0.05, 0.07]}


# Execute GridSearchCV
grid = GridSearchCV(pipe, param_grid, cv=7, scoring='accuracy', n_jobs=-1, verbose=1)
grid.fit(X_train, y_train)

# Retrieve top 5 models
cv_results = grid.cv_results_
top_5_indices = np.argsort(cv_results['mean_test_score'])[::-1][:5]

print("=== Top 5 models through cross validation ===\n")

for rank, idx in enumerate(top_5_indices):
    params = cv_results['params'][idx]
    clean_params = {k.replace("clf__", ""): v for k, v in params.items()}
    print(f"Modèle #{rank+1} - Params: {params}")
    
    # Create and fit the model with the best parameters
    model = SVC(**clean_params)
    model.fit(X_train, y_train)
    
    # Predict and evaluate
    y_pred = model.predict(X_test)
    test_acc = accuracy_score(y_test, y_pred)
    mean_cv_score = cv_results['mean_test_score'][idx]
    
    print(f"           CV Accuracy:    {mean_cv_score:.4f}")
    print(f"           Test Accuracy: {test_acc:.4f}\n")
# Out:
# Fitting 7 folds for each of 84 candidates, totalling 588 fits
# === Top 5 models through cross validation ===
#
# Modèle #1 - Params: {'clf__C': 3.5, 'clf__coef0': 0.03, 'clf__gamma': 'scale', 'clf__kernel': 'poly'}
#            CV Accuracy:    0.7990
#            Test Accuracy: 0.8895
#
# Modèle #2 - Params: {'clf__C': 2.5, 'clf__coef0': 0.03, 'clf__gamma': 'scale', 'clf__kernel': 'poly'}
#            CV Accuracy:    0.7975
#            Test Accuracy: 0.8710
#
# Modèle #3 - Params: {'clf__C': 3.7, 'clf__coef0': 0.03, 'clf__gamma': 'scale', 'clf__kernel': 'poly'}
#            CV Accuracy:    0.7975
#            Test Accuracy: 0.8870
#
# Modèle #4 - Params: {'clf__C': 3.0, 'clf__coef0': 0.05, 'clf__gamma': 'scale', 'clf__kernel': 'poly'}
#            CV Accuracy:    0.7965
#            Test Accuracy: 0.8735
#
# Modèle #5 - Params: {'clf__C': 2.3, 'clf__coef0': 0.03, 'clf__gamma': 'scale', 'clf__kernel': 'poly'}
#            CV Accuracy:    0.7955
#            Test Accuracy: 0.8690

# %% [markdown]
# ### KNeighbors
#
# We explored all compatible distance `metrics` supported by `KNeighborsClassifier` without encountering any warnings. Throughout the grid search, we observed that the test accuracy improved steadily as the number of neighbors increased. The best performance was achieved with approximately **30 neighbors**, yielding a test accuracy of around **0.786**. This suggests that more global, smoothed decision boundaries were more effective on this dataset than local ones defined by fewer neighbors.

# %%
# Model parameters
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', KNeighborsClassifier())
])
param_grid = {"clf__n_neighbors": [5, 15, 25, 27, 29, 30, 35, 50], "clf__weights": ["uniform", "distance"], "clf__metric": ["euclidean", "manhattan", "cityblock", "l1", "l2"], "clf__algorithm": ["auto", "ball_tree", "kd_tree", "brute"]}

# Executer GridSearchCV
grid = GridSearchCV(pipe, param_grid, cv=7, scoring='accuracy', n_jobs=-1, verbose=3)
grid.fit(X_train, y_train)
print(f"KNeighbors:\n  Best CV Accuracy: {grid.best_score_:.4f}")
print(f"  Best Params: {grid.best_params_}")
best_model = grid.best_estimator_

# Evaluation on the test set
y_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred)

print(f"  Test set accuracy: {test_accuracy}\n")
# Out:
# Fitting 7 folds for each of 320 candidates, totalling 2240 fits
# [CV 1/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=uniform;, score=0.738 total time=   0.0s
# [CV 2/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=uniform;, score=0.710 total time=   0.0s
# [CV 6/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=uniform;, score=0.705 total time=   0.0s
# [CV 4/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=uniform;, score=0.689 total time=   0.0s
# [CV 3/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=uniform;, score=0.710 total time=   0.0s
# [CV 7/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=uniform;, score=0.688 total time=   0.0s
# [CV 2/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=distance;, score=0.710 total time=   0.0s
# [CV 3/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=distance;, score=0.710 total time=   0.0s
# [CV 5/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=uniform;, score=0.759 total time=   0.0s
# [CV 4/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=distance;, score=0.689 total time=   0.0s
# [CV 1/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=distance;, score=0.738 total time=   0.0s
# [CV 5/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=distance;, score=0.759 total time=   0.0s
# [CV 6/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=distance;, score=0.705 total time=   0.0s
# [CV 7/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=5, clf__weights=distance;, score=0.688 total time=   0.0s
# [CV 1/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=uniform;, score=0.759 total time=   0.0s
# [CV 2/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=distance;, score=0.752 total time=   0.0s
# [CV 7/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=uniform;, score=0.726 total time=   0.0s
# [CV 5/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=uniform;, score=0.759 total time=   0.0s
# [CV 2/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=uniform;, score=0.752 total time=   0.0s
# [CV 3/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=uniform;, score=0.717 total time=   0.0s
# [CV 3/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=distance;, score=0.717 total time=   0.0s
# [CV 4/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=distance;, score=0.741 total time=   0.0s
# [CV 1/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=distance;, score=0.759 total time=   0.0s
# [CV 6/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=distance;, score=0.723 total time=   0.0s
# [CV 5/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=distance;, score=0.759 total time=   0.0s
# [CV 6/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=uniform;, score=0.723 total time=   0.0s
# [CV 7/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=distance;, score=0.726 total time=   0.0s
# [CV 4/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=15, clf__weights=uniform;, score=0.741 total time=   0.0s
# [CV 3/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=uniform;, score=0.731 total time=   0.0s
# [CV 2/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=distance;, score=0.745 total time=   0.0s
# [CV 1/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=uniform;, score=0.776 total time=   0.0s
# [CV 7/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=uniform;, score=0.716 total time=   0.0s
# [CV 5/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=uniform;, score=0.787 total time=   0.0s
# [CV 4/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=distance;, score=0.717 total time=   0.0s
# [CV 3/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=distance;, score=0.731 total time=   0.0s
# [CV 1/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=distance;, score=0.776 total time=   0.0s
# [CV 5/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=distance;, score=0.787 total time=   0.0s
# [CV 6/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=uniform;, score=0.730 total time=   0.0s
# [CV 6/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=distance;, score=0.730 total time=   0.0s
# [CV 2/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=uniform;, score=0.745 total time=   0.0s
# [CV 4/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=uniform;, score=0.717 total time=   0.0s
# [CV 7/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=25, clf__weights=distance;, score=0.716 total time=   0.0s
# [CV 3/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=uniform;, score=0.731 total time=   0.0s
# [CV 4/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=distance;, score=0.717 total time=   0.0s
# [CV 5/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=uniform;, score=0.773 total time=   0.0s
# [CV 1/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=uniform;, score=0.769 total time=   0.0s
# [CV 4/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=uniform;, score=0.717 total time=   0.0s
# [CV 5/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=distance;, score=0.773 total time=   0.0s
# [CV 7/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=uniform;, score=0.723 total time=   0.0s
# [CV 6/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=distance;, score=0.726 total time=   0.0s
# [CV 1/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=29, clf__weights=uniform;, score=0.780 total time=   0.0s
# [CV 1/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=distance;, score=0.769 total time=   0.0s
# [CV 2/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=uniform;, score=0.738 total time=   0.0s
# [CV 6/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=29, clf__weights=distance;, score=0.730 total time=   0.0s
# [CV 5/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=29, clf__weights=uniform;, score=0.769 total time=   0.0s
# [CV 7/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=distance;, score=0.723 total time=   0.0s
# [CV 6/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights=uniform;, score=0.726 total time=   0.0s
# [CV 2/7] END clf__algorithm=auto, clf__metric=euclidean, clf__n_neighbors=27, clf__weights
7] END clf__algorithm=brute, clf__metric=l2, clf__n_neighbors=50, clf__weights=distance;, score=0.733 total time=   0.0s
# [CV 7/7] END clf__algorithm=brute, clf__metric=l2, clf__n_neighbors=50, clf__weights=distance;, score=0.740 total time=   0.0s
# KNeighbors:
#   Best CV Accuracy: 0.7610
#   Best Params: {'clf__algorithm': 'auto', 'clf__metric': 'manhattan', 'clf__n_neighbors': 30, 'clf__weights': 'distance'}
#   Test set accuracy: 0.787

# %% [markdown]
# ### MLPClassifier
#
# The `MLPClassifier` reached a peak test accuracy of **0.7725**, which remained below the performance achieved with `SVC`. The model was more complex and significantly slower to train, and convergence sometimes required careful tuning of learning-related parameters. One notable difficulty was selecting the right `hidden_layer_sizes`, which could heavily impacts performance but is difficult to adjust. Despite trying several configurations, we were not able to match or surpass the accuracy obtained with support vector machines.

# %%
# Model parameters
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', MLPClassifier(max_iter=5000))
])
param_grid = {"clf__hidden_layer_sizes": [(50,), (100,), (100, 50)], "clf__alpha": [0.1, 1, 2, 5], "clf__learning_rate": ["invscaling", "adaptive"], "clf__activation": ["relu", "tanh", "logistic"]}

# Execute GridSearchCV
grid = GridSearchCV(pipe, param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=3)
grid.fit(X_train, y_train)
print(f"MLPClassifier:\n  Best CV Accuracy: {grid.best_score_:.4f}")
print(f"  Best Params: {grid.best_params_}")
best_model = grid.best_estimator_

# Evaluation on the test set
y_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred)

print(f"  Test set accuracy: {test_accuracy}\n")
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 2/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(50,), clf__learning_rate=adaptive;, score=0.723 total time=   4.0s
# [CV 3/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(50,), clf__learning_rate=adaptive;, score=0.728 total time=   4.1s
# [CV 5/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(50,), clf__learning_rate=invscaling;, score=0.645 total time=   4.2s
# [CV 3/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(50,), clf__learning_rate=invscaling;, score=0.720 total time=   4.2s
# [CV 2/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(50,), clf__learning_rate=invscaling;, score=0.713 total time=   4.3s
# [CV 1/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(50,), clf__learning_rate=invscaling;, score=0.710 total time=   4.4s
# [CV 4/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(50,), clf__learning_rate=invscaling;, score=0.728 total time=   4.4s
# [CV 1/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(50,), clf__learning_rate=adaptive;, score=0.710 total time=   4.7s
# [CV 4/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(50,), clf__learning_rate=adaptive;, score=0.728 total time=   4.2s
# [CV 1/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.725 total time=   4.1s
# [CV 1/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100,), clf__learning_rate=adaptive;, score=0.715 total time=   4.1s
# [CV 5/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(50,), clf__learning_rate=adaptive;, score=0.675 total time=   4.5s
# [CV 3/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.743 total time=   4.4s
# [CV 5/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.685 total time=   4.4s
# [CV 4/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.745 total time=   4.4s
# [CV 2/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.710 total time=   4.5s
# [CV 3/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100,), clf__learning_rate=adaptive;, score=0.713 total time=   4.4s
# [CV 4/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100,), clf__learning_rate=adaptive;, score=0.733 total time=   4.1s
# [CV 2/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100,), clf__learning_rate=adaptive;, score=0.725 total time=   4.7s
# [CV 5/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100,), clf__learning_rate=adaptive;, score=0.672 total time=   4.2s
# [CV 4/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=invscaling;, score=0.715 total time=   4.6s
# [CV 3/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=invscaling;, score=0.723 total time=   6.2s
# [CV 2/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=invscaling;, score=0.733 total time=   6.3s
# [CV 1/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=invscaling;, score=0.725 total time=   6.7s
# [CV 1/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(50,), clf__learning_rate=invscaling;, score=0.728 total time=   2.5s
# [CV 2/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.705 total time=   4.9s
# [CV 5/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=invscaling;, score=0.652 total time=   5.4s
# [CV 2/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(50,), clf__learning_rate=invscaling;, score=0.750 total time=   2.9s
# [CV 1/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.710 total time=   5.6s
# [CV 4/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.720 total time=   5.6s
# [CV 3/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(50,), clf__learning_rate=invscaling;, score=0.755 total time=   2.5s
# [CV 4/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(50,), clf__learning_rate=invscaling;, score=0.765 total time=   2.5s
# [CV 3/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.703 total time=   7.4s
# [CV 2/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(50,), clf__learning_rate=adaptive;, score=0.750 total time=   1.9s
# [CV 5/5] END clf__activation=relu, clf__alpha=0.1, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.698 total time=   5.6s
# [CV 5/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(50,), clf__learning_rate=invscaling;, score=0.713 total time=   2.6s
# [CV 1/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(50,), clf__learning_rate=adaptive;, score=0.748 total time=   2.5s
# [CV 3/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(50,), clf__learning_rate=adaptive;, score=0.743 total time=   2.3s
# [CV 4/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(50,), clf__learning_rate=adaptive;, score=0.757 total time=   2.5s
# [CV 5/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(50,), clf__learning_rate=adaptive;, score=0.733 total time=   2.3s
# [CV 3/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.757 total time=   2.1s
# [CV 2/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.750 total time=   2.6s
# [CV 4/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.777 total time=   2.4s
# [CV 1/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.762 total time=   2.7s
# [CV 5/5] END clf__activation=relu, clf__alpha=1, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0
5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.735 total time=   1.0s
# [CV 4/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.713 total time=   0.7s
# [CV 3/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.690 total time=   1.0s
# [CV 1/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100,), clf__learning_rate=adaptive;, score=0.703 total time=   0.7s
# [CV 5/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100,), clf__learning_rate=invscaling;, score=0.690 total time=   0.9s
# [CV 4/5] END clf__activation=logistic, clf__alpha=2, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.703 total time=   3.1s
# [CV 2/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100,), clf__learning_rate=adaptive;, score=0.735 total time=   0.9s
# [CV 3/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100,), clf__learning_rate=adaptive;, score=0.685 total time=   0.9s
# [CV 5/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100,), clf__learning_rate=adaptive;, score=0.693 total time=   0.9s
# [CV 4/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100,), clf__learning_rate=adaptive;, score=0.705 total time=   1.0s
# [CV 2/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=invscaling;, score=0.510 total time=   1.4s
# [CV 1/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=invscaling;, score=0.510 total time=   1.6s
# [CV 3/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=invscaling;, score=0.510 total time=   1.6s
# [CV 5/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=invscaling;, score=0.507 total time=   1.4s
# [CV 2/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.510 total time=   1.2s
# [CV 3/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.510 total time=   1.3s
# [CV 4/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=invscaling;, score=0.510 total time=   1.8s
# [CV 1/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.510 total time=   1.6s
# [CV 4/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.510 total time=   1.0s
# [CV 5/5] END clf__activation=logistic, clf__alpha=5, clf__hidden_layer_sizes=(100, 50), clf__learning_rate=adaptive;, score=0.507 total time=   0.9s
# MLPClassifier:
#   Best CV Accuracy: 0.7685
#   Best Params: {'clf__activation': 'relu', 'clf__alpha': 5, 'clf__hidden_layer_sizes': (100, 50), 'clf__learning_rate': 'adaptive'}
#   Test set accuracy: 0.7725

# %% [markdown]
# ### AdaBoostClassifier
#
# The `AdaBoostClassifier` reached a peak test accuracy of **0.7475**, which remained below the performance of `SVC`. Although it outperformed logistic regression, it did not clearly surpass other non-linear models such as `KNeighborsClassifier` or `MLPClassifier`. In practice, training was relatively slow due to the sequential nature of boosting and the increasing number of estimators. Overall, AdaBoost failed to reach the target accuracy and was not competitive with the best-performing models.

# %%
# Model parameters
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', AdaBoostClassifier())
])
param_grid = {"clf__n_estimators": [100, 200, 300, 500, 700], "clf__learning_rate": [0.01, 0.02, 0.05, 0.1, 0.05, 1]}

# Execute GridSearchCV
grid = GridSearchCV(pipe, param_grid, cv=7, scoring='accuracy', n_jobs=-1, verbose=3)
grid.fit(X_train, y_train)
print(f"AdaBoost:\n  Best CV Accuracy: {grid.best_score_:.4f}")
print(f"  Best Params: {grid.best_params_}")
best_model = grid.best_estimator_

# Evaluation on the test set
y_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred)

print(f"  Test set accuracy: {test_accuracy}\n")
# Out:
# Fitting 7 folds for each of 30 candidates, totalling 210 fits
# [CV 2/7] END clf__learning_rate=0.01, clf__n_estimators=100;, score=0.692 total time=   0.9s
# [CV 1/7] END clf__learning_rate=0.01, clf__n_estimators=100;, score=0.647 total time=   0.9s
# [CV 6/7] END clf__learning_rate=0.01, clf__n_estimators=100;, score=0.653 total time=   0.9s
# [CV 5/7] END clf__learning_rate=0.01, clf__n_estimators=100;, score=0.710 total time=   0.9s
# [CV 3/7] END clf__learning_rate=0.01, clf__n_estimators=100;, score=0.650 total time=   0.9s
# [CV 4/7] END clf__learning_rate=0.01, clf__n_estimators=100;, score=0.668 total time=   1.0s
# [CV 7/7] END clf__learning_rate=0.01, clf__n_estimators=100;, score=0.698 total time=   1.0s
# [CV 1/7] END clf__learning_rate=0.01, clf__n_estimators=200;, score=0.650 total time=   2.3s
# [CV 2/7] END clf__learning_rate=0.01, clf__n_estimators=200;, score=0.717 total time=   2.5s
# [CV 4/7] END clf__learning_rate=0.01, clf__n_estimators=200;, score=0.664 total time=   2.5s
# [CV 5/7] END clf__learning_rate=0.01, clf__n_estimators=200;, score=0.720 total time=   2.5s
# [CV 3/7] END clf__learning_rate=0.01, clf__n_estimators=200;, score=0.650 total time=   2.5s
# [CV 7/7] END clf__learning_rate=0.01, clf__n_estimators=200;, score=0.712 total time=   2.4s
# [CV 6/7] END clf__learning_rate=0.01, clf__n_estimators=200;, score=0.663 total time=   2.5s
# [CV 1/7] END clf__learning_rate=0.01, clf__n_estimators=300;, score=0.710 total time=   3.4s
# [CV 2/7] END clf__learning_rate=0.01, clf__n_estimators=300;, score=0.713 total time=   2.7s
# [CV 3/7] END clf__learning_rate=0.01, clf__n_estimators=300;, score=0.668 total time=   2.5s
# [CV 7/7] END clf__learning_rate=0.01, clf__n_estimators=300;, score=0.716 total time=   2.5s
# [CV 5/7] END clf__learning_rate=0.01, clf__n_estimators=300;, score=0.727 total time=   2.5s
# [CV 4/7] END clf__learning_rate=0.01, clf__n_estimators=300;, score=0.678 total time=   2.7s
# [CV 6/7] END clf__learning_rate=0.01, clf__n_estimators=300;, score=0.660 total time=   2.8s
# [CV 1/7] END clf__learning_rate=0.01, clf__n_estimators=500;, score=0.706 total time=   4.8s
# [CV 2/7] END clf__learning_rate=0.01, clf__n_estimators=500;, score=0.724 total time=   5.2s
# [CV 3/7] END clf__learning_rate=0.01, clf__n_estimators=500;, score=0.671 total time=   5.0s
# [CV 6/7] END clf__learning_rate=0.01, clf__n_estimators=500;, score=0.667 total time=   4.6s
# [CV 5/7] END clf__learning_rate=0.01, clf__n_estimators=500;, score=0.745 total time=   5.0s
# [CV 4/7] END clf__learning_rate=0.01, clf__n_estimators=500;, score=0.689 total time=   5.1s
# [CV 7/7] END clf__learning_rate=0.01, clf__n_estimators=500;, score=0.702 total time=   5.0s
# [CV 1/7] END clf__learning_rate=0.02, clf__n_estimators=100;, score=0.650 total time=   0.9s
# [CV 1/7] END clf__learning_rate=0.01, clf__n_estimators=700;, score=0.699 total time=   6.5s
# [CV 2/7] END clf__learning_rate=0.02, clf__n_estimators=100;, score=0.717 total time=   0.9s
# [CV 3/7] END clf__learning_rate=0.02, clf__n_estimators=100;, score=0.650 total time=   0.9s
# [CV 4/7] END clf__learning_rate=0.02, clf__n_estimators=100;, score=0.664 total time=   1.0s
# [CV 5/7] END clf__learning_rate=0.02, clf__n_estimators=100;, score=0.720 total time=   1.1s
# [CV 6/7] END clf__learning_rate=0.02, clf__n_estimators=100;, score=0.663 total time=   0.9s
# [CV 2/7] END clf__learning_rate=0.01, clf__n_estimators=700;, score=0.720 total time=   6.6s
# [CV 7/7] END clf__learning_rate=0.02, clf__n_estimators=100;, score=0.716 total time=   1.0s
# [CV 3/7] END clf__learning_rate=0.01, clf__n_estimators=700;, score=0.685 total time=   6.8s
# [CV 4/7] END clf__learning_rate=0.01, clf__n_estimators=700;, score=0.689 total time=   6.6s
# [CV 1/7] END clf__learning_rate=0.02, clf__n_estimators=200;, score=0.710 total time=   2.0s
# [CV 2/7] END clf__learning_rate=0.02, clf__n_estimators=200;, score=0.724 total time=   1.9s
# [CV 5/7] END clf__learning_rate=0.01, clf__n_estimators=700;, score=0.734 total time=   6.9s
# [CV 7/7] END clf__learning_rate=0.01, clf__n_estimators=700;, score=0.709 total time=   6.6s
# [CV 3/7] END clf__learning_rate=0.02, clf__n_estimators=200;, score=0.671 total time=   1.9s
# [CV 6/7] END clf__learning_rate=0.01, clf__n_estimators=700;, score=0.674 total time=   6.9s
# [CV 4/7] END clf__learning_rate=0.02, clf__n_estimators=200;, score=0.685 total time=   1.9s
# [CV 5/7] END clf__learning_rate=0.02, clf__n_estimators=200;, score=0.745 total time=   1.9s
# [CV 6/7] END clf__learning_rate=0.02, clf__n_estimators=200;, score=0.667 total time=   1.8s
# [CV 7/7] END clf__learning_rate=0.02, clf__n_estimators=200;, score=0.705 total time=   1.9s
# [CV 1/7] END clf__learning_rate=0.02, clf__n_estimators=300;, score=0.699 total time=   2.8s
# [CV 2/7] END clf__learning_rate=0.02, clf__n_estimators=300;, score=0.720 total time=   2.7s
# [CV 3/7] END clf__learning_rate=0.02, clf__n_estimators=300;, score=0.682 total time=   2.7s
# [CV 4/7] END clf__learning_rate=0.02, clf__n_estimators=300;, score=0.689 total time=   2.7s
# [CV 5/7] END clf__learning_rate=0.02, clf__n_estimators=300;, score=0.734 total time=   2.8s
# [CV 6/7] END clf__learning_rate=0.02, clf__n_estimators=300;, score=0.670 total time=   2.8s
# [CV 7/7] END clf__learning_rate=0.02, clf__n_estimators=300;, score=0.705 total time=   2.9s
# [CV 1/7] END clf__learning_rate=0.02, clf__n_estimators=500;, score=0.696 total time=   4.6s
# [CV 2/7] END clf__learning_rate=0.02, clf__n_estimators=500;, score=0.724 total time=   4.7s
# [CV 3/7] END clf__learning_rate=0.02, clf__n_estimators=500;, score=0.692 total time=   4.8s
# [CV 4/7] END clf__learning_rate=0.02, clf__n_estimators=500;, score=0.696 total time=   4.7s
# [CV 5/7] END clf__learning_rate=0.02, clf__n_estimators=500;, score=0.731 total time=   4.9s
# [CV 6/7] END clf__learning_rate=0.02, clf__n_estimators=500;, score=0.684 total time=   5.0s
# [CV 7/7] END clf__learning_rate=0.02, clf__n_estimators=500;, score=0.709 total time=   5.0s
# [CV 1/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.706 total time=   1.1s
# [CV 1/7] END clf__learning_rate=0.02, clf__n_estimators=700;, score=0.706 total time=   7.0s
# [CV 2/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.724 total time=   1.1s
# [CV 3/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.671 total time=   0.9s
# [CV 4/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.689 total time=   1.0s
# [CV 2/7] END clf__learning_rate=0.02, clf__n_estimators=700;, score=0.731 total time=   7.0s
# [CV 5/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.748 total time=   0.9s
# [CV 6/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.667 total time=   1.0s
# [CV 7/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.702 total time=   1.0s
# [CV 5/7] END clf__learning_rate=0.02, clf__n_estimators=700;, score=0.731 total time=   6.8s
# [CV 4/7] END clf__learning_rate=0.02, clf__n_estimators=700;, score=0.696 total time=   7.1s
# [CV 3/7] END clf__learning_rate=0.02, clf__n_estimators=700;, score=0.703 total time=   7.3s
# [CV 1/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.699 total time=   2.0s
# [CV 6/7] END clf__learning_rate=0.02, clf__n_estimators=700;, score=0.705 total time=   7.0s
# [CV 2/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.724 total time=   1.9s
# [CV 7/7] END clf__learning_rate=0.02, clf__n_estimators=700;, score=0.702 total time=   7.1s
# [CV 3/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.692 total time=   2.0s
# [CV 4/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.696 total time=   1.9s
# [CV 6/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.684 total time=   1.9s
# [CV 5/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.731 total time=   2.1s
# [CV 7/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.705 total time=   1.9s
# [CV 1/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.703 total time=   2.8s
# [CV 2/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.731 total time=   2.9s
# [CV 3/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.692 total time=   2.8s
# [CV 4/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.696 total time=   3.0s
# [CV 5/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.731 total time=   2.9s
# [CV 6/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.709 total time=   2.8s
# [CV 7/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.702 total time=   2.8s
# [CV 1/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.703 total time=   4.9s
# [CV 3/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.699 total time=   4.9s
# [CV 2/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.734 total time=   5.1s
# [CV 4/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.699 total time=   5.3s
# [CV 5/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.731 total time=   5.2s
# [CV 6/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.709 total time=   5.2s
# [CV 7/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.712 total time=   5.1s
# [CV 1/7] END clf__learning_rate=0.1, clf__n_estimators=100;, score=0.703 total time=   1.0s
# [CV 2/7] END clf__learning_rate=0.1, clf__n_estimators=100;, score=0.720 total time=   1.0s
# [CV 1/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.703 total time=   7.3s
# [CV 3/7] END clf__learning_rate=0.1, clf__n_estimators=100;, score=0.685 total time=   1.0s
# [CV 4/7] END clf__learning_rate=0.1, clf__n_estimators=100;, score=0.692 total time=   1.0s
# [CV 5/7] END clf__learning_rate=0.1, clf__n_estimators=100;, score=0.731 total time=   1.0s
# [CV 6/7] END clf__learning_rate=0.1, clf__n_estimators=100;, score=0.688 total time=   0.9s
# [CV 2/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.745 total time=   7.4s
# [CV 7/7] END clf__learning_rate=0.1, clf__n_estimators=100;, score=0.705 total time=   1.0s
# [CV 3/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.703 total time=   7.1s
# [CV 4/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.706 total time=   7.2s
# [CV 5/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.734 total time=   7.0s
# [CV 1/7] END clf__learning_rate=0.1, clf__n_estimators=200;, score=0.703 total time=   2.0s
# [CV 6/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.705 total time=   7.0s
# [CV 2/7] END clf__learning_rate=0.1, clf__n_estimators=200;, score=0.724 total time=   2.0s
# [CV 7/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.719 total time=   7.1s
# [CV 3/7] END clf__learning_rate=0.1, clf__n_estimators=200;, score=0.703 total time=   1.9s
# [CV 4/7] END clf__learning_rate=0.1, clf__n_estimators=200;, score=0.699 total time=   1.9s
# [CV 5/7] END clf__learning_rate=0.1, clf__n_estimators=200;, score=0.731 total time=   1.9s
# [CV 6/7] END clf__learning_rate=0.1, clf__n_estimators=200;, score=0.712 total time=   2.0s
# [CV 7/7] END clf__learning_rate=0.1, clf__n_estimators=200;, score=0.716 total time=   2.0s
# [CV 1/7] END clf__learning_rate=0.1, clf__n_estimators=300;, score=0.699 total time=   3.0s
# [CV 2/7] END clf__learning_rate=0.1, clf__n_estimators=300;, score=0.731 total time=   3.1s
# [CV 4/7] END clf__learning_rate=0.1, clf__n_estimators=300;, score=0.699 total time=   3.0s
# [CV 3/7] END clf__learning_rate=0.1, clf__n_estimators=300;, score=0.703 total time=   3.1s
# [CV 5/7] END clf__learning_rate=0.1, clf__n_estimators=300;, score=0.734 total time=   3.2s
# [CV 6/7] END clf__learning_rate=0.1, clf__n_estimators=300;, score=0.709 total time=   3.2s
# [CV 7/7] END clf__learning_rate=0.1, clf__n_estimators=300;, score=0.719 total time=   3.1s
# [CV 1/7] END clf__learning_rate=0.1, clf__n_estimators=500;, score=0.699 total time=   4.9s
# [CV 3/7] END clf__learning_rate=0.1, clf__n_estimators=500;, score=0.699 total time=   4.8s
# [CV 2/7] END clf__learning_rate=0.1, clf__n_estimators=500;, score=0.738 total time=   5.0s
# [CV 4/7] END clf__learning_rate=0.1, clf__n_estimators=500;, score=0.710 total time=   4.8s
# [CV 5/7] END clf__learning_rate=0.1, clf__n_estimators=500;, score=0.748 total time=   5.1s
# [CV 6/7] END clf__learning_rate=0.1, clf__n_estimators=500;, score=0.709 total time=   5.0s
# [CV 7/7] END clf__learning_rate=0.1, clf__n_estimators=500;, score=0.709 total time=   5.0s
# [CV 1/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.706 total time=   1.0s
# [CV 2/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.724 total time=   1.1s
# [CV 1/7] END clf__learning_rate=0.1, clf__n_estimators=700;, score=0.696 total time=   7.0s
# [CV 3/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.671 total time=   1.1s
# [CV 4/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.689 total time=   1.1s
# [CV 2/7] END clf__learning_rate=0.1, clf__n_estimators=700;, score=0.741 total time=   6.7s
# [CV 5/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.748 total time=   1.1s
# [CV 6/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.667 total time=   1.2s
# [CV 7/7] END clf__learning_rate=0.05, clf__n_estimators=100;, score=0.702 total time=   1.3s
# [CV 3/7] END clf__learning_rate=0.1, clf__n_estimators=700;, score=0.706 total time=   7.3s
# [CV 4/7] END clf__learning_rate=0.1, clf__n_estimators=700;, score=0.713 total time=   7.6s
# [CV 5/7] END clf__learning_rate=0.1, clf__n_estimators=700;, score=0.752 total time=   7.4s
# [CV 1/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.699 total time=   2.3s
# [CV 6/7] END clf__learning_rate=0.1, clf__n_estimators=700;, score=0.709 total time=   7.6s
# [CV 7/7] END clf__learning_rate=0.1, clf__n_estimators=700;, score=0.716 total time=   7.7s
# [CV 2/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.724 total time=   2.2s
# [CV 3/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.692 total time=   2.1s
# [CV 4/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.696 total time=   2.2s
# [CV 5/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.731 total time=   2.1s
# [CV 6/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.684 total time=   2.1s
# [CV 7/7] END clf__learning_rate=0.05, clf__n_estimators=200;, score=0.705 total time=   2.1s
# [CV 1/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.703 total time=   3.2s
# [CV 2/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.731 total time=   3.1s
# [CV 3/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.692 total time=   3.2s
# [CV 4/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.696 total time=   3.3s
# [CV 5/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.731 total time=   3.3s
# [CV 6/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.709 total time=   3.4s
# [CV 7/7] END clf__learning_rate=0.05, clf__n_estimators=300;, score=0.702 total time=   3.4s
# [CV 1/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.703 total time=   5.6s
# [CV 3/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.699 total time=   5.6s
# [CV 4/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.699 total time=   5.7s
# [CV 2/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.734 total time=   6.1s
# [CV 5/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.731 total time=   5.8s
# [CV 6/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.709 total time=   5.6s
# [CV 7/7] END clf__learning_rate=0.05, clf__n_estimators=500;, score=0.712 total time=   5.7s
# [CV 1/7] END clf__learning_rate=1, clf__n_estimators=100;, score=0.664 total time=   1.3s
# [CV 2/7] END clf__learning_rate=1, clf__n_estimators=100;, score=0.724 total time=   2.1s
# [CV 1/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.703 total time=   9.0s
# [CV 3/7] END clf__learning_rate=1, clf__n_estimators=100;, score=0.657 total time=   1.1s
# [CV 4/7] END clf__learning_rate=1, clf__n_estimators=100;, score=0.703 total time=   1.1s
# [CV 5/7] END clf__learning_rate=1, clf__n_estimators=100;, score=0.752 total time=   1.1s
# [CV 6/7] END clf__learning_rate=1, clf__n_estimators=100;, score=0.702 total time=   1.1s
# [CV 2/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.745 total time=   9.2s
# [CV 7/7] END clf__learning_rate=1, clf__n_estimators=100;, score=0.726 total time=   1.5s
# [CV 3/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.703 total time=   9.4s
# [CV 5/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.734 total time=   9.2s
# [CV 4/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.706 total time=   9.4s
# [CV 1/7] END clf__learning_rate=1, clf__n_estimators=200;, score=0.671 total time=   2.6s
# [CV 2/7] END clf__learning_rate=1, clf__n_estimators=200;, score=0.734 total time=   2.3s
# [CV 6/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.705 total time=   9.6s
# [CV 7/7] END clf__learning_rate=0.05, clf__n_estimators=700;, score=0.719 total time=   9.3s
# [CV 3/7] END clf__learning_rate=1, clf__n_estimators=200;, score=0.664 total time=   2.2s
# [CV 4/7] END clf__learning_rate=1, clf__n_estimators=200;, score=0.706 total time=   2.2s
# [CV 5/7] END clf__learning_rate=1, clf__n_estimators=200;, score=0.745 total time=   2.1s
# [CV 6/7] END clf__learning_rate=1, clf__n_estimators=200;, score=0.705 total time=   2.1s
# [CV 7/7] END clf__learning_rate=1, clf__n_estimators=200;, score=0.726 total time=   2.2s
# [CV 1/7] END clf__learning_rate=1, clf__n_estimators=300;, score=0.675 total time=   4.3s
# [CV 3/7] END clf__learning_rate=1, clf__n_estimators=300;, score=0.682 total time=   4.3s
# [CV 2/7] END clf__learning_rate=1, clf__n_estimators=300;, score=0.738 total time=   4.5s
# [CV 4/7] END clf__learning_rate=1, clf__n_estimators=300;, score=0.699 total time=   4.3s
# [CV 5/7] END clf__learning_rate=1, clf__n_estimators=300;, score=0.741 total time=   4.5s
# [CV 7/7] END clf__learning_rate=1, clf__n_estimators=300;, score=0.712 total time=   4.4s
# [CV 6/7] END clf__learning_rate=1, clf__n_estimators=300;, score=0.688 total time=   4.5s
# [CV 1/7] END clf__learning_rate=1, clf__n_estimators=500;, score=0.699 total time=   6.9s
# [CV 2/7] END clf__learning_rate=1, clf__n_estimators=500;, score=0.727 total time=   5.7s
# [CV 4/7] END clf__learning_rate=1, clf__n_estimators=500;, score=0.720 total time=   5.6s
# [CV 5/7] END clf__learning_rate=1, clf__n_estimators=500;, score=0.745 total time=   5.6s
# [CV 3/7] END clf__learning_rate=1, clf__n_estimators=500;, score=0.682 total time=   5.8s
# [CV 7/7] END clf__learning_rate=1, clf__n_estimators=500;, score=0.698 total time=   5.6s
# [CV 6/7] END clf__learning_rate=1, clf__n_estimators=500;, score=0.719 total time=   5.7s
# [CV 1/7] END clf__learning_rate=1, clf__n_estimators=700;, score=0.703 total time=   7.9s
# [CV 2/7] END clf__learning_rate=1, clf__n_estimators=700;, score=0.720 total time=   7.5s
# [CV 3/7] END clf__learning_rate=1, clf__n_estimators=700;, score=0.671 total time=   7.3s
# [CV 6/7] END clf__learning_rate=1, clf__n_estimators=700;, score=0.712 total time=   7.0s
# [CV 4/7] END clf__learning_rate=1, clf__n_estimators=700;, score=0.706 total time=   7.2s
# [CV 5/7] END clf__learning_rate=1, clf__n_estimators=700;, score=0.766 total time=   7.0s
# [CV 7/7] END clf__learning_rate=1, clf__n_estimators=700;, score=0.712 total time=   6.6s
# AdaBoost:
#   Best CV Accuracy: 0.7190
#   Best Params: {'clf__learning_rate': 0.1, 'clf__n_estimators': 700}
#   Test set accuracy: 0.7475
